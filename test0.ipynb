# %%
from step1 import *

# %%
df=load_csv('AAPL')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/portfolio/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniconda3/envs/portfolio/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/portfolio/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
model=fit_model('AAPL',False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model=fit_model('AAPL',False)
#
# File ~/BeCode/portfolio-optimization/step1.py:41, in fit_model(stock_name, save, model)
#      39 # Fit the model to the data
#      40 model = model()
# ---> 41 model.fit(df)
#      42 if save==True:
#      43     directory = os.path.join(DATA_PATH, stock_name)
#
# File ~/miniconda3/envs/portfolio/lib/python3.10/site-packages/prophet/forecaster.py:1126, in Prophet.fit(self, df, **kwargs)
#    1123     raise ValueError('Dataframe has less than 2 non-NaN rows.')
#    1124 self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# -> 1126 history = self.setup_dataframe(history, initialize_scales=True)
#    1127 self.history = history
#    1128 self.set_auto_seasonalities()
#
# ...

# %%
plot_training_accuracy(stock_name='AAPL', model=model,save=False,show=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_training_accuracy(stock_name='AAPL', model=model,save=False,show=True)
#
# File ~/BeCode/portfolio-optimization/step1.py:59, in plot_training_accuracy(stock_name, model, save, show)
#      56 forecast['ds'] = forecast['ds'].dt.tz_localize('UTC').dt.tz_convert(None)
#      58 plt.plot(df['ds'], df['y'], label='Actual')
# ---> 59 plt.plot(forecast['ds'], forecast['yhat'], label='Predicted')
#      60 plt.legend()
#      61 plt.title('Training Set Accuracy')
#
# File ~/miniconda3/envs/portfolio/lib/python3.10/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
# ...
